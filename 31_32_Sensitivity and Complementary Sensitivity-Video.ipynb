# %% [markdown]
# # Goals of feedback

# %% [markdown]
# 1.Stablity(design)
# 2.Uncertainity(compensation)
# 3.Disturbance(Rejection)
# 4.Noise(Attenuation)

# %% [markdown]
# # System flow

# %% [markdown]
# ![loop.JPG](attachment:loop.JPG)

# %% [markdown]
# Loop transfer function =combination of controller K and System P. L=PK
#
# Our Equation becomes,
#
# Y=Pd d+ PK(ε)= Pd d+ PK(r-ym)
# Y=Pd d+PK(r-y-n)-----------(1)
# In these equations we will consider it as matrix equation. So  equn (1) becomes
# I Y=Pd d+PK(r-y-n)----------(2)
# I Y=Pd d+PK r-PK y-PK n
# (I+PK) y=PK r+Pd d-PK n
# Ym=〖(𝐼+𝑃𝐾)〗^(−1)  (PK r)  +〖(𝐼+𝑃𝐾)〗^(−1)Pd d- 〖(𝐼+𝑃𝐾)〗^(−1)PK n--------(3)
# Where 〖(𝐼+𝑃𝐾)〗^(−1)=sensitivity,s and
# 〖(𝐼+𝑃𝐾)〗^(−1)PK=complementary sensitivity

# %% [markdown]
# So ,PK=L
# So S=〖(𝐼+𝐿)〗^(−1)
# T=〖(𝐼+𝐿)〗^(−1)L
# Now,its easy to show S+T=I-------- for all frequencies

# %% [markdown]
# Design K,so that S and T have beneficiary properties to attenuate noise,reduce disturbances and increase stability.
# ε = r-Ym
# =r- 〖(𝐼+𝑃𝐾)〗^(−1) PK r +〖(𝐼+𝑃𝐾)〗^(−1) Pd d – 〖(𝐼+𝑃𝐾)〗^(−1) PK n--------(4)
# We know 〖(𝐼+𝑃𝐾)〗^(−1) PK=T
# Equn (4) becomes
# =r- Tr - 〖(𝐼+𝑃𝐾)〗^(−1)Pd d + 〖(𝐼+𝑃𝐾)〗^(−1)PK n
# = r(I-T) - 〖(𝐼+𝑃𝐾)〗^(−1)Pd d + 〖(𝐼+𝑃𝐾)〗^(−1)PK n
# We know S+T=I
# Then
# Ε =r S- S Pd d +T n-------------(5)
# For control system, its difficult to control for a fast changing system .only when it is slow moving, it will be possible to track.

# %% [markdown]
# ![bode.JPG](attachment:bode.JPG)

# %% [markdown]
# Attaching the videos

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/hTu36q5yx20" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/hTu36q5yx20" frameborder="0" allowfullscreen></iframe>

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/hEQdr1G5H2w" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/hEQdr1G5H2w" frameborder="0" allowfullscreen></iframe>
