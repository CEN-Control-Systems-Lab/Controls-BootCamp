# %%
# Loop shaping

# %%
# %%HTML youtube video link
# <iframe width="560" height="315" src="https://www.youtube.com/embed/sfNwLmgK5sE" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/sfNwLmgK5sE" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>

# %% [markdown]
# $
# L=P*K
# $<br>
# $
# S=(I+L)^{-1}
# $<br>
# $
# T=(I+L)^{-1}
# $<br>
# $
# S+T=I
# $

# %% [markdown]
# Goals of Feedback
#
# - Stability
#
# - Uncertainity Compensation
#
# - Disturbance rejection
#
# - Noise Attenuation

# %% [markdown]
# $Ym=(((I+P*K)^{-1})* P*K*r)+(((I+P*K)^{-1} )*Pd*d )- (((I+P*K)^{-1} )*P*K*n)$

# %% [markdown]
# $e=r - Ym$

# %% [markdown]
# $e=S*r-S*Pd*d+T*n$

# %% [markdown]
# #loop shaping in Cruise control

# %% [markdown]
# $P(s)=1/(s+1)$

# %% [markdown]
# Ideally
#
# $L=P*K=1/s$
#
# Arbitrarly
#
# $((1/(s+1)K=10/s$
#
# $K=10(s+1)/s$

# %%
# %%HTML youtube video link
# <iframe width="560" height="315" src="https://www.youtube.com/embed/fkYcCCujOjc" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/fkYcCCujOjc" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>

# %% [markdown]
# $Closed loop System$

# %% [markdown]
# $Figure shown below$

# %% [markdown]
# ![controller.jpg](attachment:controller.jpg)
