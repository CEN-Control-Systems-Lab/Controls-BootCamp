# %% [markdown]
# # Linear quadratic Gaussian Regulator
#                                                                                     Name:Mygapula D V Prasad
#                                                                                     Roll no:CB.EN.P2AEL17014

# %% [markdown]
# ## Linear quadratic Gaussian Regulator:
#
# When we use the combination of an optimal estimator and an optimal regulator to design the controller, the compensator
# is called Linear Quadratic Gaussian (LQG).
#
# The great news about an LQG design is that stability of the closed-loop system is guaranteed and the entire process
# is fast and can be automated.

# %%
from IPython.display import Image
Image(filename='C:/Users/durgavenkataprasad/Desktop/New folder/1.png')

# %% [markdown]
# ## Linear Quadratic Guassian:
#
# When we use the combination of an optimal estimator and an optimal regulator to design the controller, the compensator is called Linear Quadratic Gaussian (LQG).
#
# The linear–quadratic–Gaussian (LQG) control problem is one of the most fundamental optimal control
# problems. It concerns linear systems driven by additive white Gaussian noise. The problem is to determine an output
# feedback law that is optimal in the sense of minimizing the expected value of a quadratic cost criterion.
# Output measurements are assumed to be corrupted by Gaussian noise and the initial state, likewise, is assumed to be a Gaussian random vector.the LQG controller, is unique and it is simply a combination of a Kalman filter, i.e. a linear–quadratic state estimator (LQE), together with a linear–quadratic regulator (LQR).. The separation principle states that the state estimator and the state feedback can be designed independently. LQG control applies to both linear time-invariant systems as well as linear time-varying systems, and constitutes a linear dynamic feedback control law that is easily computed and implemented.
#
# Linear system which are both controllable and observable.We can develop optimal feedback control through LQR and also develop an optimal kalman gain using matrices A and C. LQR is choosen to place the eigen values of closed loop system.LQE is used to place the eigen values of estimated dynamics.
#
# The great news about an LQG design is that stability of the closed-loop system is guaranteed and the entire process is fast and can be automated.

# %%
from IPython.display import Image
Image(filename='C:/Users/durgavenkataprasad/Desktop/New folder/2.png')

# %% [markdown]
# u=input of the system
#
# x=first state of output/position of the cart
#
# x= position vector it consist of all states as mentioned in the above figure.

# %% [markdown]
# #### Cart-pole Simulation:

# %%
from IPython.display import Image
Image(filename='C:/Users/durgavenkataprasad/Desktop/New folder/4.png')

# %% [markdown]
# Cartpend_ sim: It is basically a ‘C’ code that simulates the four non linear dynamics of the system.
#
# essentially output vector split in to four components x,$\dot{x}$,θ, $\dot{\theta}$
#
# For non linear systems pendulum up position θ=π, but LQR is linearized that position.
#
# We need to look into local coordinate’s θ-π, so we have to subtract the equilibrium from the state of the non linear
# system.
#
# In the simulink, a step is provides that will change the ‘x ‘position from 0-1 at t=10, this step going to be an
# equilibrium reference condition for the cart position ‘x’  i.e. the cart pole is moving from 0 to 1

# %% [markdown]
# ##### LQR Simple way of explanation:
#
# For non linear dynamics, measured the four states and subtracted the nominal equilibrium position and connected to the input of the system through the LQR feedback (-Kx).

# %% [markdown]
# #### The simulated output:

# %%
from IPython.display import Image
Image(filename='C:/Users/durgavenkataprasad/Desktop/New folder/5.png')

# %% [markdown]
# The red color signal indicates the θ  and the value is π as shown in above figure

# %% [markdown]
# #The red color signal indicates θ and the vlaue  is π as shown in above figure.
#
# Yellow color indicates the system position changes from 0 to 1 at time=10.
#
# Little dips are observed in the θ and $\dot{\theta}$
#
# Kalman filter needs to know the input of the system and the output of the kalman filter $\hat{X}$ is estimate  the four states
# of the output.

# %% [markdown]
# #### Kalman filter block in the simulink

# %%
from IPython.display import Image
Image(filename='C:/Users/durgavenkataprasad/Desktop/New folder/6.png')

# %% [markdown]
# In this simulator A matrix is kalman filter.a and b matrix is kalman filter.b etc.
#
# In LQG system the output y is not consisting four states it needs to estimate the four states of the system with the kalman filter.
#
# After defined A, B, C and D matrices and disturbance and noise covariance matrices need to calculate kalman filter gain by using the LQE and LQR command.
#
# Need to build linear system called sys kalman filter that is dynamical system is estimated as shown in the above diagram.

# %% [markdown]
# #### Robustness:
# wrote Doyle in 1978 Some remarkable paper on LQG i.e guaranted state margins.
#
# This paper says no guaranteed stability margins for LQG Regulators. Depents of the my system,types of noises and disturbances,  combined LQR and LQG might be arbitarily sensitive to things like model uncertainty and time delays.
#
# The stability of the system does not guarantee the robustness of the system and hence new concept comes called robustness.
#
# Closed loop Eigen values and how fast estimate the system decides the performance of the system.

# %% [markdown]
# video_23:https://www.youtube.com/watch?v=reRT8LbPhBs&index=24&list=PLMrJAkhIeNNR20Mz-VpzgfQs5zrYi085m&t=0s

# %% [markdown]
# video_24:https://www.youtube.com/watch?v=Y6MRgg_TGy0&index=25&list=PLMrJAkhIeNNR20Mz-VpzgfQs5zrYi085m&t=0s
